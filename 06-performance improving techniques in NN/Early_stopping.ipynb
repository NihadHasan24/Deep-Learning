# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from pylab import rcParams
import matplotlib.pyplot as plt
import warnings
from mlxtend.plotting import plot_decision_regions
from matplotlib.colors import ListedColormap
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_circles
import seaborn as sns

# %%
X, y = make_circles(n_samples=100, noise=0.1, random_state=1)

# %%
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=y)
# Out:
# <Axes: >

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=2)

# %%
model = Sequential()

model.add(Dense(256, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.13/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=3500, verbose=0)

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
plot_decision_regions(X_test, y_test.ravel(), clf = model, legend=2)
plt.show()
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 12s 1ms/step

# %% [markdown]
# **Early Stopping**

# %%
model = Sequential()

model.add(Dense(256, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
callback = EarlyStopping(
    monitor="val_loss",
    min_delta=0.00001,
    patience=50,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False
)

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=3500, callbacks=callback)
# Out:
# Epoch 1/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.4750 - loss: 0.6957 - val_accuracy: 0.5500 - val_loss: 0.6917
# Epoch 2/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5125 - loss: 0.6931 - val_accuracy: 0.5500 - val_loss: 0.6958
# Epoch 3/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5000 - loss: 0.6908 - val_accuracy: 0.4500 - val_loss: 0.6977
# Epoch 4/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.4875 - loss: 0.6902 - val_accuracy: 0.3000 - val_loss: 0.6998
# Epoch 5/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5250 - loss: 0.6883 - val_accuracy: 0.4500 - val_loss: 0.7004
# Epoch 6/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5500 - loss: 0.6874 - val_accuracy: 0.4500 - val_loss: 0.7023
# Epoch 7/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5625 - loss: 0.6862 - val_accuracy: 0.4500 - val_loss: 0.7043
# Epoch 8/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5500 - loss: 0.6854 - val_accuracy: 0.4500 - val_loss: 0.7067
# Epoch 9/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5500 - loss: 0.6844 - val_accuracy: 0.4500 - val_loss: 0.7086
# Epoch 10/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5500 - loss: 0.6837 - val_accuracy: 0.4500 - val_loss: 0.7109
# Epoch 11/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5625 - loss: 0.6830 - val_accuracy: 0.4500 - val_loss: 0.7123
# Epoch 12/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5625 - loss: 0.6820 - val_accuracy: 0.4500 - val_loss: 0.7138
# Epoch 13/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5750 - loss: 0.6811 - val_accuracy: 0.4500 - val_loss: 0.7148
# Epoch 14/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5625 - loss: 0.6803 - val_accuracy: 0.4000 - val_loss: 0.7150
# Epoch 15/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5625 - loss: 0.6798 - val_accuracy: 0.4000 - val_loss: 0.7157
# Epoch 16/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5625 - loss: 0.6790 - val_accuracy: 0.4000 - val_loss: 0.7160
# Epoch 17/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5625 - loss: 0.6781 - val_accuracy: 0.4000 - val_loss: 0.7150
# Epoch 18/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5625 - loss: 0.6778 - val_accuracy: 0.4000 - val_loss: 0.7139
# Epoch 19/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5875 - loss: 0.6770 - val_accuracy: 0.4000 - val_loss: 0.7138
# Epoch 20/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5625 - loss: 0.6765 - val_accuracy: 0.4000 - val_loss: 0.7145
# Epoch 21/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5750 - loss: 0.6757 - val_accuracy: 0.4000 - val_loss: 0.7155
# Epoch 22/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5875 - loss: 0.6750 - val_accuracy: 0.4000 - val_loss: 0.7164
# Epoch 23/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5750 - loss: 0.6745 - val_accuracy: 0.4000 - val_loss: 0.7171
# Epoch 24/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5625 - loss: 0.6737 - val_accuracy: 0.4000 - val_loss: 0.7180
# Epoch 25/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5625 - loss: 0.6734 - val_accuracy: 0.4000 - val_loss: 0.7187
# Epoch 26/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5750 - loss: 0.6726 - val_accuracy: 0.4000 - val_loss: 0.7186
# Epoch 27/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5750 - loss: 0.6716 - val_accuracy: 0.4000 - val_loss: 0.7177
# Epoch 28/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5750 - loss: 0.6709 - val_accuracy: 0.4000 - val_loss: 0.7171
# Epoch 29/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5750 - loss: 0.6704 - val_accuracy: 0.4000 - val_loss: 0.7167
# Epoch 30/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5750 - loss: 0.6694 - val_accuracy: 0.4000 - val_loss: 0.7155
# Epoch 31/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5625 - loss: 0.6689 - val_accuracy: 0.4000 - val_loss: 0.7145
# Epoch 32/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5750 - loss: 0.6681 - val_accuracy: 0.4000 - val_loss: 0.7127
# Epoch 33/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5750 - loss: 0.6674 - val_accuracy: 0.4000 - val_loss: 0.7115
# Epoch 34/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6000 - loss: 0.6667 - val_accuracy: 0.4500 - val_loss: 0.7106
# Epoch 35/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5875 - loss: 0.6661 - val_accuracy: 0.4000 - val_loss: 0.7096
# Epoch 36/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6125 - loss: 0.6653 - val_accuracy: 0.4000 - val_loss: 0.7102
# Epoch 37/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6000 - loss: 0.6647 - val_accuracy: 0.4000 - val_loss: 0.7112
# Epoch 38/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6125 - loss: 0.6636 - val_accuracy: 0.5000 - val_loss: 0.7107
# Epoch 39/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5875 - loss: 0.6632 - val_accuracy: 0.5000 - val_loss: 0.7098
# Epoch 40/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5875 - loss: 0.6620 - val_accuracy: 0.5000 - val_loss: 0.7092
# Epoch 41/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5875 - loss: 0.6614 - val_accuracy: 0.5000 - val_loss: 0.7087
# Epoch 42/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6125 - loss: 0.6608 - val_accuracy: 0.5000 - val_loss: 0.7072
# Epoch 43/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6000 - loss: 0.6601 - val_accuracy: 0.5000 - val_loss: 0.7076
# Epoch 44/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6125 - loss: 0.6595 - val_accuracy: 0.5000 - val_loss: 0.7075
# Epoch 45/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6250 - loss: 0.6582 - val_accuracy: 0.5000 - val_loss: 0.7084
# Epoch 46/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6125 - loss: 0.6581 - val_accuracy: 0.5000 - val_loss: 0.7104
# Epoch 47/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6250 - loss: 0.6566 - val_accuracy: 0.4500 - val_loss: 0.7112
# Epoch 48/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6125 - loss: 0.6558 - val_accuracy: 0.4500 - val_loss: 0.7118
# Epoch 49/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6125 - loss: 0.6552 - val_accuracy: 0.5000 - val_loss: 0.7122
# Epoch 50/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6250 - loss: 0.6544 - val_accuracy: 0.5000 - val_loss: 0.7120
# Epoch 51/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6000 - loss: 0.6533 - val_accuracy: 0.5000 - val_loss: 0.7122
# Epoch 51: early stopping

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
plot_decision_regions(X_test, y_test.ravel(), clf = model, legend=2)
plt.show()
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 13s 1ms/step
